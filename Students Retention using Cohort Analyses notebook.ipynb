# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\KENNETH\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Data Assessing

# %%
std_df= pd.read_excel("transaction.xlsx")

# %%
std_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
std_df.head(10)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
# 5               6          25         2339       2017-03-08           1.0
# 6               7          22         1542       2017-04-21           1.0
# 7               8          15         2459       2017-07-15           0.0
# 8               9          67         1305       2017-08-10           0.0
# 9              10          12         3262       2017-08-30           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# ...

# %%
std_df.tail(8)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 19992           19993          13            5       2017-04-28           0.0
# 19993           19994          77         2618       2017-12-23           0.0
# 19994           19995           9          718       2017-05-13           1.0
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
#       order_status           brand product_line product_class product_size  \
# 19992     Approved           Solex     Standard        medium       medium
# 19993     Approved  Norco Bicycles         Road        medium        large
# ...

# %%
std_df.duplicated().sum()
# Out:
# 0

# %%
std_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    20000 non-null  int64
#  1   product_id        20000 non-null  int64
#  2   customer_id       20000 non-null  int64
#  3   transaction_date  20000 non-null  datetime64[ns]
#  4   online_order      19640 non-null  float64
#  5   order_status      20000 non-null  object
#  6   brand             19803 non-null  object
#  7   product_line      19803 non-null  object
#  8   product_class     19803 non-null  object
#  9   product_size      19803 non-null  object
#  10  list_price        20000 non-null  float64
#  11  standard_cost     19803 non-null  float64
#  12  transaction_id.1  20000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
std_df.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  transaction_id.1
# count   19803.000000      20000.000000
# mean      556.046951      -4334.217050
# std       405.955660       4076.640921
# min         7.210000     -13317.666667
# 25%       215.140000      -7657.583333
# ...

# %%
std_df.isna().sum()
# Out:
# transaction_id        0
# product_id            0
# customer_id           0
# transaction_date      0
# online_order        360
# order_status          0
# brand               197
# product_line        197
# product_class       197
# product_size        197
# list_price            0
# standard_cost       197
# transaction_id.1      0
# dtype: int64

# %% [markdown]
# # Data Wrangling (Cleaning)

# %%
# Fill in the missing values in online_order with mean
online_order_mode = std_df['online_order'].mode()
std_df.online_order.fillna(online_order_mode, inplace=True)

# %% [markdown]
# # Alternative approach for online_order

# %%
std_df.online_order.value_counts()
# Out:
# 1.000000    9829
# 0.000000    9811
# 0.500458     360
# Name: online_order, dtype: int64

# %%
# Since online_order values are in binary form, we can use (1.0)
std_df.online_order.fillna(1.0, inplace= True)

# %%
# for brand
brand_mode = std_df['brand'].mode()
std_df.brand.fillna(brand_mode, inplace=True)

# %%
# for product_line
product_line_mode = std_df['product_line'].mode()
std_df.product_line.fillna(product_line_mode, inplace= True)

# %%
# For product_class
product_class_mode = std_df['product_class'].mode()
std_df.product_class.fillna(product_class_mode, inplace = True)

# %%
# for product_size  
product_size_mode = std_df['product_size'].mode()
std_df.product_size.fillna(product_size_mode, inplace= True)

# %%
# For standard_cost 
standard_cost_mean = round(std_df['standard_cost'].mean(), 0)
std_df.standard_cost.fillna(standard_cost_mean, inplace = True)

# %%
import datetime as dt

# %%
# transactionmonth
# cohortmonth
# cohortindex

# %%
date_extract=lambda x: (x.year, x.month, 1)

# %%
# Then apply it to the transaction_date
std_df.transaction_date.apply(date_extract)
# Out:
# 0         (2017, 2, 1)
# 1         (2017, 5, 1)
# 2        (2017, 10, 1)
# 3         (2017, 8, 1)
# 4        (2017, 10, 1)
#              ...
# 19995     (2017, 6, 1)
# 19996    (2017, 11, 1)
# 19997     (2017, 4, 1)
# 19998     (2017, 7, 1)
# 19999     (2017, 9, 1)
# Name: transaction_date, Length: 20000, dtype: object

# %%
# Convert it to datetime
date_extract=lambda x:dt.datetime(x.year, x.month, 1)

# %%
std_df.transaction_date
# Out:
# 0       2017-02-25
# 1       2017-05-21
# 2       2017-10-16
# 3       2017-08-31
# 4       2017-10-01
#            ...
# 19995   2017-06-24
# 19996   2017-11-09
# 19997   2017-04-14
# 19998   2017-07-03
# 19999   2017-09-22
# Name: transaction_date, Length: 20000, dtype: datetime64[ns]

# %%
std_df['transactionMonth']= std_df.transaction_date.apply(date_extract)

# %%
std_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
# To get the cohortMonth, make a query for a particular customer,
std_df.query('customer_id==2950')
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 11064           11065           1         2950       2017-10-16           0.0
# 18922           18923          62         2950       2017-04-26           0.0
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 11064     Approved  Giant Bicycles     Standard        medium       medium
# 18922     Approved           Solex     Standard        medium       medium
#
#        list_price  standard_cost  transaction_id.1 transactionMonth  \
# 0           71.49          53.62       3933.333333       2017-02-01
# 11064     1403.50         954.82      -3443.000000       2017-10-01
# 18922      478.16         298.72      -8661.333333       2017-04-01
#
#         CohortMonth
# 0      (2017, 2, 1)
# 11064  (2017, 2, 1)
# ...

# %%
# Then use groupby to capture all the transactions made by the customer
std_df['CohortMonth']=std_df.groupby('customer_id')['transactionMonth'].transform(min)

# %%
std_df.query('customer_id==2950')
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 11064           11065           1         2950       2017-10-16           0.0
# 18922           18923          62         2950       2017-04-26           0.0
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 11064     Approved  Giant Bicycles     Standard        medium       medium
# 18922     Approved           Solex     Standard        medium       medium
#
#        list_price  standard_cost  transaction_id.1 transactionMonth  \
# 0           71.49          53.62       3933.333333       2017-02-01
# 11064     1403.50         954.82      -3443.000000       2017-10-01
# 18922      478.16         298.72      -8661.333333       2017-04-01
#
#       CohortMonth
# 0      2017-02-01
# 11064  2017-02-01
# ...

# %%
# Find the cohort index
# Cohort_index = year_diff *12 + month_diff + 1

# %%
year_diff = std_df['transactionMonth'].dt.year - std_df.CohortMonth.dt.year
month_diff = std_df['transactionMonth'].dt.month - std_df.CohortMonth.dt.month

# %%
std_df['Cohort_index']= year_diff *12 + month_diff + 1

# %%
std_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
# To get the cohort data,
Cohort_data=std_df.groupby(['Cohort_index', 'CohortMonth'])['customer_id'].apply(pd.Series.nunique).reset_index()

# %% [markdown]
# # Retention metric

# %%
cohort_data_pivot=Cohort_data.pivot_table(columns="Cohort_index", index ="CohortMonth", values = "customer_id")

# %%
cohort_data_pivot
# Out:
# Cohort_index      1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2017-01-01    1354.0  486.0  508.0  509.0  502.0  483.0  518.0  529.0  500.0
# 2017-02-01     800.0  325.0  298.0  313.0  288.0  298.0  308.0  281.0  329.0
# 2017-03-01     484.0  167.0  174.0  167.0  182.0  184.0  172.0  212.0  189.0
# 2017-04-01     336.0  111.0  121.0  153.0  143.0  121.0  142.0  126.0  132.0
# 2017-05-01     210.0   85.0   81.0   87.0   71.0   74.0   73.0   81.0    NaN
# 2017-06-01     122.0   45.0   44.0   47.0   46.0   46.0   53.0    NaN    NaN
# 2017-07-01      77.0   26.0   29.0   32.0   37.0   24.0    NaN    NaN    NaN
# 2017-08-01      51.0   19.0   21.0   17.0   13.0    NaN    NaN    NaN    NaN
# 2017-09-01      23.0    7.0    7.0    9.0    NaN    NaN    NaN    NaN    NaN
# 2017-10-01      20.0    6.0    8.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-11-01      13.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
# From our cohort data, you can observe that in month of Jan, 1354 customers registered and you can read their performance in the same row

# %%
# Convert it percentage
(1354.0/1354.0)*100
# Out:
# 100.0

# %%
# to get 400 percentage of 1354
round((400/1354)*100,2)
# Out:
# 29.54

# %%
dvd = cohort_data_pivot.iloc[:, 0]

# %%
dvd
# Out:
# CohortMonth
# 2017-01-01    1354.0
# 2017-02-01     800.0
# 2017-03-01     484.0
# 2017-04-01     336.0
# 2017-05-01     210.0
# 2017-06-01     122.0
# 2017-07-01      77.0
# 2017-08-01      51.0
# 2017-09-01      23.0
# 2017-10-01      20.0
# 2017-11-01      13.0
# 2017-12-01       4.0
# Name: 1, dtype: float64

# %%
# Convert to percentage and 2 decimal places
round(cohort_data_pivot.divide(dvd, axis = 0)*100, 2)
# Out:
# Cohort_index     1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2017-01-01    100.0  35.89  37.52  37.59  37.08  35.67  38.26  39.07  36.93
# 2017-02-01    100.0  40.62  37.25  39.12  36.00  37.25  38.50  35.12  41.12
# 2017-03-01    100.0  34.50  35.95  34.50  37.60  38.02  35.54  43.80  39.05
# 2017-04-01    100.0  33.04  36.01  45.54  42.56  36.01  42.26  37.50  39.29
# 2017-05-01    100.0  40.48  38.57  41.43  33.81  35.24  34.76  38.57    NaN
# 2017-06-01    100.0  36.89  36.07  38.52  37.70  37.70  43.44    NaN    NaN
# 2017-07-01    100.0  33.77  37.66  41.56  48.05  31.17    NaN    NaN    NaN
# 2017-08-01    100.0  37.25  41.18  33.33  25.49    NaN    NaN    NaN    NaN
# 2017-09-01    100.0  30.43  30.43  39.13    NaN    NaN    NaN    NaN    NaN
# 2017-10-01    100.0  30.00  40.00    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-11-01    100.0  38.46    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
final =round(cohort_data_pivot.divide(dvd, axis = 0)*100, 2)
final.index = final.index.strftime('%Y-%m')

# %%
# Initialize the figure
plt.figure(figsize=(16, 10))
# Adding a title
plt.title('Average Standard Cost: Monthly Cohort', fontsize = 14)
# Creating the heatmap
sns.heatmap(final, annot = True, vmin = 0.0, vmax = 100, cmap = 'RdYlBu', fmt = 'g')
plt.ylabel('Cohort Month')
plt.xlabel('Cohort Index')
plt.yticks(rotation='360')
plt.show()
